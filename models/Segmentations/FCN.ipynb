# %% [markdown]
# ## Import Libraries

# %%
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader
from torchsummary import summary
from torch.optim import lr_scheduler
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
import os
from PIL import Image
from torch.nn.functional import log_softmax

torch.cuda.empty_cache()
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.enabled = True

# %% [markdown]
# ## Utils/Functions

# %%
class basic_fcn(nn.Module):
    def __init__(self, ipchn=3, padd=1, n_class=21, initial_conv_padd=100, mpstride=2):
        super().__init__()
        
        #*************************** Econder Layers ***************************# 
        # Convolution layer 1
        self.conv1_1 = nn.Conv2d(ipchn, 32, 3, padding=initial_conv_padd)
        self.relu1_1 = nn.ReLU(inplace=True)
        self.conv1_2 = nn.Conv2d(32, 32, 3, padding=padd)
        self.relu1_2 = nn.ReLU(inplace=True)
        self.pool1 = nn.MaxPool2d(2, stride=mpstride, ceil_mode=True)  # 1/2

        # Convolution layer 2
        self.conv2_1 = nn.Conv2d(32, 64, 3, padding=padd)
        self.relu2_1 = nn.ReLU(inplace=True)
        self.conv2_2 = nn.Conv2d(64, 64, 3, padding=padd)
        self.relu2_2 = nn.ReLU(inplace=True)
        self.pool2 = nn.MaxPool2d(2, stride=mpstride, ceil_mode=True)  # 1/4

        # Convolution layer 3
        self.conv3_1 = nn.Conv2d(64, 128, 3, padding=padd)
        self.relu3_1 = nn.ReLU(inplace=True)
        self.conv3_2 = nn.Conv2d(128, 128, 3, padding=padd)
        self.relu3_2 = nn.ReLU(inplace=True)
        self.conv3_3 = nn.Conv2d(128, 128, 3, padding=padd)
        self.relu3_3 = nn.ReLU(inplace=True)
        self.pool3 = nn.MaxPool2d(2, stride=mpstride, ceil_mode=True)  # 1/8

        # Convolution layer 4
        self.conv4_1 = nn.Conv2d(128, 256, 3, padding=padd)
        self.relu4_1 = nn.ReLU(inplace=True)
        self.conv4_2 = nn.Conv2d(256, 256, 3, padding=padd)
        self.relu4_2 = nn.ReLU(inplace=True)
        self.conv4_3 = nn.Conv2d(256, 256, 3, padding=padd)
        self.relu4_3 = nn.ReLU(inplace=True)
        self.pool4 = nn.MaxPool2d(2, stride=mpstride, ceil_mode=True)  # 1/16

        # Convolution layer 5
        self.conv5_1 = nn.Conv2d(256, 256, 3, padding=padd)
        self.relu5_1 = nn.ReLU(inplace=True)
        self.conv5_2 = nn.Conv2d(256, 256, 3, padding=padd)
        self.relu5_2 = nn.ReLU(inplace=True)
        self.conv5_3 = nn.Conv2d(256, 256, 3, padding=padd)
        self.relu5_3 = nn.ReLU(inplace=True)
        self.pool5 = nn.MaxPool2d(2, stride=mpstride, ceil_mode=True)  # 1/32

        # Fully Connected Layer 1, Total Layer 6
        self.fc6 = nn.Conv2d(256, 512, 3)
        self.relu6 = nn.ReLU(inplace=True)
        self.drop6 = nn.Dropout2d()

        # Fully Connected Layer 2, Total Layer 7
        self.fc7 = nn.Conv2d(512, 1024, 3)
        self.relu7 = nn.ReLU(inplace=True)
        self.drop7 = nn.Dropout2d()

        #*************************** Decoder Layers ***************************#
        self.relu    = nn.ReLU(inplace=True)
        self.deconv6 = nn.ConvTranspose2d(1024, 512, kernel_size=3, stride=1)
        self.deconv5 = nn.ConvTranspose2d(512, 256, kernel_size=3, stride=1)
        self.deconv4 = nn.ConvTranspose2d(256, 256, kernel_size=3, stride=2, padding=1, dilation=1)
        self.deconv3 = nn.ConvTranspose2d(256, 128, kernel_size=3, stride=2, padding=1, dilation=4)
        self.deconv2 = nn.ConvTranspose2d(128, 64, kernel_size=3, stride=2, padding=1, dilation=2)
        self.deconv1 = nn.ConvTranspose2d(64, 32, kernel_size=4, stride=2, padding=1, dilation=1)
        self.classifier = nn.Conv2d(32, n_class, kernel_size=1, padding=1)



    def forward(self, x):
        h = x
        h = self.relu1_1(self.conv1_1(h))
        h = self.relu1_2(self.conv1_2(h))
        h = self.pool1(h)

        h = self.relu2_1(self.conv2_1(h))
        h = self.relu2_2(self.conv2_2(h))
        h = self.pool2(h)

        h = self.relu3_1(self.conv3_1(h))
        h = self.relu3_2(self.conv3_2(h))
        h = self.relu3_3(self.conv3_3(h))
        h = self.pool3(h)

        h = self.relu4_1(self.conv4_1(h))
        h = self.relu4_2(self.conv4_2(h))
        h = self.relu4_3(self.conv4_3(h))
        h = self.pool4(h)
        out4 =h
 
        h = self.relu5_1(self.conv5_1(h))
        h = self.relu5_2(self.conv5_2(h))
        h = self.relu5_3(self.conv5_3(h))
        h = self.pool5(h)
        out5 = h

        h = self.relu6(self.fc6(h))
        h = self.drop6(h)
        out6 = h

        h = self.relu7(self.fc7(h))
        h = self.drop7(h)

        h = self.relu(self.deconv6(h))               
        h = h + out6 
        h = self.relu(self.deconv5(h))
        h = h + out5
        h = self.relu(self.deconv4(h))
        h = h + out4
        h = self.relu(self.deconv3(h))
        h = self.relu(self.deconv2(h))
        h = self.relu(self.deconv1(h))
        h = self.classifier(h)           

        return h


def validate_seg_model(epoch, model, val_loader, n_class, iu_scores, pixel_scores):
    model.eval()
    total_pixels = 0
    correct_pixels = 0
    iou_per_class = np.zeros(n_class)
    iou_counts = np.zeros(n_class)

    with torch.no_grad():
        for batch in val_loader:
            images = batch[0].cuda()
            true_masks = batch[1].cuda()

            outputs = model(images)
            preds = torch.argmax(outputs, dim=1)

            for cls in range(n_class):
                pred_inds = (preds == cls)
                target_inds = (true_masks == cls)

                intersection = (pred_inds & target_inds).sum().item()
                union = (pred_inds | target_inds).sum().item()

                if union > 0:
                    iou_per_class[cls] += intersection / union
                    iou_counts[cls] += 1

            correct_pixels += (preds == true_masks).sum().item()
            total_pixels += torch.numel(true_masks)

    mean_iou = (iou_per_class / np.maximum(iou_counts, 1)).mean()
    pixel_accuracy = correct_pixels / total_pixels

    iu_scores[epoch, :] = iou_per_class / np.maximum(iou_counts, 1)
    pixel_scores[epoch] = pixel_accuracy

    print(f"[Validation Epoch {epoch}] Pixel Accuracy: {pixel_accuracy:.4f} | Mean IoU: {mean_iou:.4f}")



def seg_train(model,epochs,train_loader,val_loader,optimizer,criterion,n_class):
    model.train()
    loss_track=[]
    iu_scores    = np.zeros((epochs, n_class))
    pixel_scores = np.zeros(epochs)

    for epoch in range(epochs):
        loss_train=0.0
        for iter, batch in enumerate(train_loader):
            optimizer.zero_grad()

            inputs = batch[0].cuda()
            labels = batch[1].cuda()

            outputs = model(inputs)
            #outputs = log_softmax(outputs, dim=1)
            #outputs = torch.argmax(outputs, dim=1).to(torch.float32)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            loss_train += loss.item()
        
        loss_track.append(loss_train/iter)
        if epoch ==0 or epoch % 2 == 0:
            print("epoch{}, loss: {}".format(epoch, loss_train/iter))

        validate_seg_model(epoch, model, val_loader, n_class, iu_scores, pixel_scores)
        
    return loss_track,iu_scores,pixel_scores


class voc_data_load(torch.utils.data.Dataset):
    def __init__(self,rootpath,folder_data,folder_mask,filelist,n_class,colormap,download=0):
        
        if download==1:
            input_transforms = transforms.Compose([
                transforms.Resize((256, 256)),
                transforms.ToTensor(),
            ])
            train_dataset = torchvision.datasets.VOCSegmentation(
                root=rootpath,
                year='2012',
                image_set='train',
                download=True,
                transform=input_transforms
            )

        self.img_folder = folder_data
        self.seg_folder = folder_mask
        self.img_list = os.listdir(folder_data)
        self.seg_list = os.listdir(folder_mask)
        self.transform = transforms.Compose([
                            transforms.Resize((256, 256)),
                            transforms.ToTensor(),
                            transforms.Normalize(mean=[0.485, 0.456, 0.406],std=[0.229, 0.224, 0.225])])
        
        
        self.filelist = filelist
        self.n_class = n_class
        self.colormap = colormap
    
    def __len__(self):
        return len(self.filelist)
    
    def __getitem__(self,idx):
        img = Image.open(self.img_folder + "/" + self.filelist[idx] + ".jpg").convert('RGB')
        img = self.transform(img)
        
        seg = Image.open(self.seg_folder + "/" + self.filelist[idx] + ".png").convert("RGB")

        seg = seg.resize((256, 256), Image.NEAREST)
        seg = np.array(seg)
        segmentation_mask = np.zeros((256, 256, len(self.colormap)), dtype=np.float32)
        for label_index, label in enumerate(self.colormap):
            segmentation_mask[:, :, label_index] = np.all(seg == label, axis=-1).astype(float)
        segmentation_mask = np.transpose(segmentation_mask,(2,0,1))
        segmentation_mask = torch.from_numpy(segmentation_mask)
        segmentation_mask = segmentation_mask.argmax(dim=0).squeeze().long()

        return img, segmentation_mask
    

label_name = ["background", "aeroplane", "bicycle", "bird", "boat",
              "bottle", "bus", "car", "cat", "chair", "cow", "dining table",
              "dog", "horse", "motorbike", "person", "potted plant",
              "sheep", "sofa", "train", "tv/monitor"]

label_color = [[0, 0, 0], [128, 0, 0], [0, 128, 0], [128, 128, 0], [0, 0, 128],
               [128, 0, 128], [0, 128, 128], [128, 128, 128], [64, 0, 0], [192, 0, 0],
               [64, 128, 0], [192, 128, 0], [64, 0, 128], [192, 0, 128],
               [64, 128, 128], [192, 128, 128], [0, 64, 0], [128, 64, 0],
               [0, 192, 0], [128, 192, 0], [0, 64, 128]
               ]

# %% [markdown]
# ## Load Data and Display Sample

# %%
##Load Training Data
n_class=21
rootpath = "/home/urseismoadmin/Documents/PRJ_DL_PRACTICE/ECE_484_Coursework/HW5/data"
trainpath = "/home/urseismoadmin/Documents/PRJ_DL_PRACTICE/ECE_484_Coursework/HW5/data/VOCdevkit/VOC2012/ImageSets/Segmentation/train.txt"
readfunc = open(trainpath, "r").read().split('\n')
readfunc = readfunc[:1464]
original_images = "/home/urseismoadmin/Documents/PRJ_DL_PRACTICE/ECE_484_Coursework/HW5/data/VOCdevkit/VOC2012/JPEGImages"
segmentation_mask = "/home/urseismoadmin/Documents/PRJ_DL_PRACTICE/ECE_484_Coursework/HW5/data/VOCdevkit/VOC2012/SegmentationClass"
traindataset = voc_data_load(rootpath,original_images,segmentation_mask,readfunc,n_class,label_color)
train_loader = DataLoader(traindataset, batch_size=8, shuffle=True, num_workers=16)


##Load Validation Data
valpath = "/home/urseismoadmin/Documents/PRJ_DL_PRACTICE/ECE_484_Coursework/HW5/data/VOCdevkit/VOC2012/ImageSets/Segmentation/val.txt"
readfunc = open(valpath, "r").read().split('\n')
readfunc = readfunc[:1449]
valdataset = voc_data_load(rootpath,original_images,segmentation_mask,readfunc,n_class,label_color)
val_loader = DataLoader(valdataset, batch_size=4, num_workers=16)

# %%
img, seg = next(iter(train_loader))

print('Image Dimension in a Batch:', img.shape)
print('Seg Dimension in a Batch:', seg.shape)
print("Label unique classes:", torch.unique(seg))

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.imshow(np.transpose(img[1], (1, 2, 0)))
plt.title('Original Train Image')

plt.subplot(1,2,2)
plt.imshow(seg[1])
plt.title('Segmented Train Image')
plt.tight_layout()
plt.show()
print(np.unique(seg.numpy(), return_counts=True))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Image Dimension in a Batch: torch.Size([8, 3, 256, 256])
# Seg Dimension in a Batch: torch.Size([8, 256, 256])
# Label unique classes: tensor([ 0,  1,  3,  4, 10, 15, 16, 20])
# (array([ 0,  1,  3,  4, 10, 15, 16, 20]), array([433862,   2192,  20808,   2518,   3725,  20007,  13689,  27487]))

# %%
img, seg = next(iter(val_loader))

print('Image Dimension in a Batch:', img.shape)
print('Seg Dimension in a Batch:', seg.shape)
print("Label unique classes:", torch.unique(seg))

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.imshow(np.transpose(img[0], (1, 2, 0)))
plt.title('Original Validation Image')

plt.subplot(1,2,2)
plt.imshow(seg[0])
plt.title('Segmented Validation Image')
plt.tight_layout()
plt.show()
print(np.unique(seg.numpy(), return_counts=True))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Image Dimension in a Batch: torch.Size([4, 3, 256, 256])
# Seg Dimension in a Batch: torch.Size([4, 256, 256])
# Label unique classes: tensor([ 0,  1,  4, 19])
# (array([ 0,  1,  4, 19]), array([184480,  11076,   4184,  62404]))

# %% [markdown]
# ## Model Training

# %%
## If Model is trained then load trained model and evaluate results. Else start a new training
model_path = "/home/urseismoadmin/Documents/PRJ_DL_PRACTICE/ECE_484_Coursework/HW5/models/basic_fcn_v0.pth"

if os.path.exists(model_path):
    fcn_model = basic_fcn().cuda()
    fcn_model.load_state_dict(model_path)
else:
    lr = 1e-4
    epochs = 250
    n_class = 21
    ipchn = 3
    momentum = 0.99
    w_decay = 1e-5

    fcn_model = basic_fcn().cuda()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(fcn_model.parameters(), lr=lr)

    loss_track,iu_scores,pixel_scores = seg_train(fcn_model,epochs,train_loader,val_loader,optimizer,criterion,n_class)
    torch.save(fcn_model.state_dict(), "/home/urseismoadmin/Documents/PRJ_DL_PRACTICE/ECE_484_Coursework/HW5/models/basic_fcn_v0.pth")
# Out:
# epoch0, loss: 1.9045457388018514
# [Validation Epoch 0] Pixel Accuracy: 0.7195 | Mean IoU: 0.0344
# [Validation Epoch 1] Pixel Accuracy: 0.7194 | Mean IoU: 0.0344
# epoch2, loss: 1.3303997081059675
# [Validation Epoch 2] Pixel Accuracy: 0.7194 | Mean IoU: 0.0344
# [Validation Epoch 3] Pixel Accuracy: 0.7194 | Mean IoU: 0.0343
# epoch4, loss: 1.3067137612091315
# [Validation Epoch 4] Pixel Accuracy: 0.7194 | Mean IoU: 0.0343
# [Validation Epoch 5] Pixel Accuracy: 0.7194 | Mean IoU: 0.0343
# epoch6, loss: 1.3038957927908217
# [Validation Epoch 6] Pixel Accuracy: 0.7194 | Mean IoU: 0.0343
# [Validation Epoch 7] Pixel Accuracy: 0.7194 | Mean IoU: 0.0343
# epoch8, loss: 1.292636275618941
# [Validation Epoch 8] Pixel Accuracy: 0.7194 | Mean IoU: 0.0343
# [Validation Epoch 9] Pixel Accuracy: 0.7194 | Mean IoU: 0.0343
# epoch10, loss: 1.2907715344822013
# [Validation Epoch 10] Pixel Accuracy: 0.7194 | Mean IoU: 0.0343
# [Validation Epoch 11] Pixel Accuracy: 0.7194 | Mean IoU: 0.0343
# epoch12, loss: 1.2654538534499786
# [Validation Epoch 12] Pixel Accuracy: 0.7194 | Mean IoU: 0.0343
# [Validation Epoch 13] Pixel Accuracy: 0.7194 | Mean IoU: 0.0343
# epoch14, loss: 1.2711900492290875
# [Validation Epoch 14] Pixel Accuracy: 0.7194 | Mean IoU: 0.0343
# [Validation Epoch 15] Pixel Accuracy: 0.7332 | Mean IoU: 0.0349
# epoch16, loss: 1.2530018932871767
# [Validation Epoch 16] Pixel Accuracy: 0.7332 | Mean IoU: 0.0349
# [Validation Epoch 17] Pixel Accuracy: 0.7333 | Mean IoU: 0.0349
# epoch18, loss: 1.270342448255518
# [Validation Epoch 18] Pixel Accuracy: 0.7333 | Mean IoU: 0.0349
# [Validation Epoch 19] Pixel Accuracy: 0.7333 | Mean IoU: 0.0349
# epoch20, loss: 1.242997795670897
# [Validation Epoch 20] Pixel Accuracy: 0.7333 | Mean IoU: 0.0349
# [Validation Epoch 21] Pixel Accuracy: 0.7333 | Mean IoU: 0.0349
# epoch22, loss: 1.2346696178991716
# [Validation Epoch 22] Pixel Accuracy: 0.7333 | Mean IoU: 0.0349
# [Validation Epoch 23] Pixel Accuracy: 0.7333 | Mean IoU: 0.0349
# epoch24, loss: 1.2281702301659427
# [Validation Epoch 24] Pixel Accuracy: 0.7333 | Mean IoU: 0.0349
# [Validation Epoch 25] Pixel Accuracy: 0.7333 | Mean IoU: 0.0349
# epoch26, loss: 1.2100370932411362
# [Validation Epoch 26] Pixel Accuracy: 0.7333 | Mean IoU: 0.0350
# [Validation Epoch 27] Pixel Accuracy: 0.7330 | Mean IoU: 0.0353
# epoch28, loss: 1.2021881964180496
# [Validation Epoch 28] Pixel Accuracy: 0.7330 | Mean IoU: 0.0353
# [Validation Epoch 29] Pixel Accuracy: 0.7331 | Mean IoU: 0.0352
# epoch30, loss: 1.1919028002482195
# [Validation Epoch 30] Pixel Accuracy: 0.7332 | Mean IoU: 0.0353
# [Validation Epoch 31] Pixel Accuracy: 0.7329 | Mean IoU: 0.0358
# epoch32, loss: 1.1683025808779748
# [Validation Epoch 32] Pixel Accuracy: 0.7330 | Mean IoU: 0.0365
# [Validation Epoch 33] Pixel Accuracy: 0.7336 | Mean IoU: 0.0353
# epoch34, loss: 1.154347497355807
# [Validation Epoch 34] Pixel Accuracy: 0.7472 | Mean IoU: 0.0382
# [Validation Epoch 35] Pixel Accuracy: 0.7481 | Mean IoU: 0.0376
# epoch36, loss: 1.1345895743304557
# [Validation Epoch 36] Pixel Accuracy: 0.7484 | Mean IoU: 0.0380
# [Validation Epoch 37] Pixel Accuracy: 0.7456 | Mean IoU: 0.0403
# epoch38, loss: 1.1201932646416046
# [Validation Epoch 38] Pixel Accuracy: 0.7462 | Mean IoU: 0.0398
# [Validation Epoch 39] Pixel Accuracy: 0.7477 | Mean IoU: 0.0391
# epoch40, loss: 1.0945426400873688
# [Validation Epoch 40] Pixel Accuracy: 0.7475 | Mean IoU: 0.0392
# [Validation Epoch 41] Pixel Accuracy: 0.7488 | Mean IoU: 0.0390
# epoch42, loss: 1.0701954318926885
# [Validation Epoch 42] Pixel Accuracy: 0.7488 | Mean IoU: 0.0378
# [Validation Epoch 43] Pixel Accuracy: 0.7486 | Mean IoU: 0.0387
# epoch44, loss: 1.0328555680238283
# [Validation Epoch 44] Pixel Accuracy: 0.7452 | Mean IoU: 0.0398
# [Validation Epoch 45] Pixel Accuracy: 0.7451 | Mean IoU: 0.0417
# epoch46, loss: 1.014378214602942
# [Validation Epoch 46] Pixel Accuracy: 0.7472 | Mean IoU: 0.0386
# [Validation Epoch 47] Pixel Accuracy: 0.7464 | Mean IoU: 0.0404
# epoch48, loss: 0.9670604552541461
# [Validation Epoch 48] Pixel Accuracy: 0.7464 | Mean IoU: 0.0421
# [Validation Epoch 49] Pixel Accuracy: 0.7424 | Mean IoU: 0.0430
# epoch50, loss: 0.9324315231252502
# [Validation Epoch 50] Pixel Accuracy: 0.7439 | Mean IoU: 0.0413
# [Validation Epoch 51] Pixel Accuracy: 0.7472 | Mean IoU: 0.0412
# epoch52, loss: 0.8950349575543142
# [Validation Epoch 52] Pixel Accuracy: 0.7448 | Mean IoU: 0.0420
# [Validation Epoch 53] Pixel Accuracy: 0.7423 | Mean IoU: 0.0430
# epoch54, loss: 0.8475560960206356
# [Validation Epoch 54] Pixel Accuracy: 0.7290 | Mean IoU: 0.0462
# [Validation Epoch 55] Pixel Accuracy: 0.7427 | Mean IoU: 0.0439
# epoch56, loss: 0.8070128109756407
# [Validation Epoch 56] Pixel Accuracy: 0.7421 | Mean IoU: 0.0449
# [Validation Epoch 57] Pixel Accuracy: 0.7448 | Mean IoU: 0.0440
# epoch58, loss: 0.78213835810567
# [Validation Epoch 58] Pixel Accuracy: 0.7345 | Mean IoU: 0.0461
# [Validation Epoch 59] Pixel Accuracy: 0.7389 | Mean IoU: 0.0462
# epoch60, loss: 0.7316112799958868
# [Validation Epoch 60] Pixel Accuracy: 0.7351 | Mean IoU: 0.0457
# [Validation Epoch 61] Pixel Accuracy: 0.7321 | Mean IoU: 0.0477
# epoch62, loss: 0.7015419284720997
# [Validation Epoch 62] Pixel Accuracy: 0.7337 | Mean IoU: 0.0453
# [Validation Epoch 63] Pixel Accuracy: 0.7264 | Mean IoU: 0.0481
# epoch64, loss: 0.6796802007235013
# [Validation Epoch 64] Pixel Accuracy: 0.7272 | Mean IoU: 0.0460
# [Validation Epoch 65] Pixel Accuracy: 0.7387 | Mean IoU: 0.0460
# epoch66, loss: 0.6428948524561557
# [Validation Epoch 66] Pixel Accuracy: 0.7183 | Mean IoU: 0.0490
# [Validation Epoch 67] Pixel Accuracy: 0.7262 | Mean IoU: 0.0481
# epoch68, loss: 0.6174541325359554
# [Validation Epoch 68] Pixel Accuracy: 0.7390 | Mean IoU: 0.0465
# [Validation Epoch 69] Pixel Accuracy: 0.7246 | Mean IoU: 0.0470
# epoch70, loss: 0.5894798736323367
# [Validation Epoch 70] Pixel Accuracy: 0.7352 | Mean IoU: 0.0471
# [Validation Epoch 71] Pixel Accuracy: 0.7217 | Mean IoU: 0.0485
# epoch72, loss: 0.556378341801874
# [Validation Epoch 72] Pixel Accuracy: 0.7216 | Mean IoU: 0.0497
# [Validation Epoch 73] Pixel Accuracy: 0.7070 | Mean IoU: 0.0491
# epoch74, loss: 0.5659473481086584
# [Validation Epoch 74] Pixel Accuracy: 0.7278 | Mean IoU: 0.0485
# [Validation Epoch 75] Pixel Accuracy: 0.7192 | Mean IoU: 0.0489
# epoch76, loss: 0.5001749890027466
# [Validation Epoch 76] Pixel Accuracy: 0.7230 | Mean IoU: 0.0504
# [Validation Epoch 77] Pixel Accuracy: 0.7162 | Mean IoU: 0.0506
# epoch78, loss: 0.5087325073533006
# [Validation Epoch 78] Pixel Accuracy: 0.7164 | Mean IoU: 0.0474
# [Validation Epoch 79] Pixel Accuracy: 0.7214 | Mean IoU: 0.0491
# epoch80, loss: 0.4870428763903104
# [Validation Epoch 80] Pixel Accuracy: 0.7089 | Mean IoU: 0.0499
# [Validation Epoch 81] Pixel Accuracy: 0.7085 | Mean IoU: 0.0472
# epoch82, loss: 0.4420912842174153
# [Validation Epoch 82] Pixel Accuracy: 0.7235 | Mean IoU: 0.0492
# [Validation Epoch 83] Pixel Accuracy: 0.7180 | Mean IoU: 0.0492
# epoch84, loss: 0.4617048185114022
# [Validation Epoch 84] Pixel Accuracy: 0.7237 | Mean IoU: 0.0480
# [Validation Epoch 85] Pixel Accuracy: 0.7268 | Mean IoU: 0.0486
# epoch86, loss: 0.41081614055476345
# [Validation Epoch 86] Pixel Accuracy: 0.7134 | Mean IoU: 0.0508
# [Validation Epoch 87] Pixel Accuracy: 0.7123 | Mean IoU: 0.0460
# epoch88, loss: 0.4335868831027995
# [Validation Epoch 88] Pixel Accuracy: 0.7030 | Mean IoU: 0.0497
# [Validation Epoch 89] Pixel Accuracy: 0.7216 | Mean IoU: 0.0473
# epoch90, loss: 0.4011894450574131
# [Validation Epoch 90] Pixel Accuracy: 0.7120 | Mean IoU: 0.0517
# [Validation Epoch 91] Pixel Accuracy: 0.7083 | Mean IoU: 0.0501
# epoch92, loss: 0.3553943810882149
# [Validation Epoch 92] Pixel Accuracy: 0.7187 | Mean IoU: 0.0499
# [Validation Epoch 93] Pixel Accuracy: 0.7080 | Mean IoU: 0.0517
# epoch94, loss: 0.33897513699728055
# [Validation Epoch 94] Pixel Accuracy: 0.7035 | Mean IoU: 0.0497
# [Validation Epoch 95] Pixel Accuracy: 0.7237 | Mean IoU: 0.0507
# epoch96, loss: 0.37243756889314444
# [Validation Epoch 96] Pixel Accuracy: 0.7225 | Mean IoU: 0.0489
# [Validation Epoch 97] Pixel Accuracy: 0.7016 | Mean IoU: 0.0519
# epoch98, loss: 0.3311517360609966
# [Validation Epoch 98] Pixel Accuracy: 0.7250 | Mean IoU: 0.0515
# [Validation Epoch 99] Pixel Accuracy: 0.7177 | Mean IoU: 0.0510
# epoch100, loss: 0.30873897884573254
# [Validation Epoch 100] Pixel Accuracy: 0.7116 | Mean IoU: 0.0518
# [Validation Epoch 101] Pixel Accuracy: 0.7107 | Mean IoU: 0.0510
# epoch102, loss: 0.28127094284518733
# [Validation Epoch 102] Pixel Accuracy: 0.7192 | Mean IoU: 0.0510
# [Validation Epoch 103] Pixel Accuracy: 0.7136 | Mean IoU: 0.0502
# epoch104, loss: 0.352487417449663
# [Validation Epoch 104] Pixel Accuracy: 0.7167 | Mean IoU: 0.0518
# [Validation Epoch 105] Pixel Accuracy: 0.7170 | Mean IoU: 0.0530
# epoch106, loss: 0.2917320550634311
# [Validation Epoch 106] Pixel Accuracy: 0.7233 | Mean IoU: 0.0511
# [Validation Epoch 107] Pixel Accuracy: 0.7121 | Mean IoU: 0.0510
# epoch108, loss: 0.2516394000459503
# [Validation Epoch 108] Pixel Accuracy: 0.7185 | Mean IoU: 0.0523
# [Validation Epoch 109] Pixel Accuracy: 0.6984 | Mean IoU: 0.0518
# epoch110, loss: 0.293863279233267
# [Validation Epoch 110] Pixel Accuracy: 0.7209 | Mean IoU: 0.0517
# [Validation Epoch 111] Pixel Accuracy: 0.7250 | Mean IoU: 0.0524
# epoch112, loss: 0.32943862480121655
# [Validation Epoch 112] Pixel Accuracy: 0.7205 | Mean IoU: 0.0520
# [Validation Epoch 113] Pixel Accuracy: 0.7240 | Mean IoU: 0.0520
# epoch114, loss: 0.24260712136606594
# [Validation Epoch 114] Pixel Accuracy: 0.7241 | Mean IoU: 0.0519
# [Validation Epoch 115] Pixel Accuracy: 0.7243 | Mean IoU: 0.0517
# epoch116, loss: 0.21073420624156575
# [Validation Epoch 116] Pixel Accuracy: 0.7245 | Mean IoU: 0.0519
# [Validation Epoch 117] Pixel Accuracy: 0.7239 | Mean IoU: 0.0505
# epoch118, loss: 0.20729734003543854
# [Validation Epoch 118] Pixel Accuracy: 0.7182 | Mean IoU: 0.0513
# [Validation Epoch 119] Pixel Accuracy: 0.7285 | Mean IoU: 0.0500
# epoch120, loss: 0.23089492263702246
# [Validation Epoch 120] Pixel Accuracy: 0.7138 | Mean IoU: 0.0532
# [Validation Epoch 121] Pixel Accuracy: 0.7102 | Mean IoU: 0.0524
# epoch122, loss: 0.3396861213412914
# [Validation Epoch 122] Pixel Accuracy: 0.7187 | Mean IoU: 0.0512
# [Validation Epoch 123] Pixel Accuracy: 0.7259 | Mean IoU: 0.0510
# epoch124, loss: 0.2464790206689101
# [Validation Epoch 124] Pixel Accuracy: 0.7201 | Mean IoU: 0.0532
# [Validation Epoch 125] Pixel Accuracy: 0.7247 | Mean IoU: 0.0530
# epoch126, loss: 0.19839303604849093
# [Validation Epoch 126] Pixel Accuracy: 0.7242 | Mean IoU: 0.0531
# [Validation Epoch 127] Pixel Accuracy: 0.7229 | Mean IoU: 0.0527
# epoch128, loss: 0.181334690037337
# [Validation Epoch 128] Pixel Accuracy: 0.7225 | Mean IoU: 0.0530
# [Validation Epoch 129] Pixel Accuracy: 0.7244 | Mean IoU: 0.0530
# epoch130, loss: 0.1825293770448847
# [Validation Epoch 130] Pixel Accuracy: 0.7203 | Mean IoU: 0.0528
# [Validation Epoch 131] Pixel Accuracy: 0.7182 | Mean IoU: 0.0536
# epoch132, loss: 0.2101020504321371
# [Validation Epoch 132] Pixel Accuracy: 0.7092 | Mean IoU: 0.0532
# [Validation Epoch 133] Pixel Accuracy: 0.7120 | Mean IoU: 0.0508
# epoch134, loss: 0.32534622859496337
# [Validation Epoch 134] Pixel Accuracy: 0.7073 | Mean IoU: 0.0524
# [Validation Epoch 135] Pixel Accuracy: 0.7195 | Mean IoU: 0.0527
# epoch136, loss: 0.22091004403901623
# [Validation Epoch 136] Pixel Accuracy: 0.7266 | Mean IoU: 0.0546
# [Validation Epoch 137] Pixel Accuracy: 0.7202 | Mean IoU: 0.0541
# epoch138, loss: 0.17897073040296743
# [Validation Epoch 138] Pixel Accuracy: 0.7197 | Mean IoU: 0.0534
# [Validation Epoch 139] Pixel Accuracy: 0.7240 | Mean IoU: 0.0529
# epoch140, loss: 0.1870397982279678
# [Validation Epoch 140] Pixel Accuracy: 0.7174 | Mean IoU: 0.0534
# [Validation Epoch 141] Pixel Accuracy: 0.7246 | Mean IoU: 0.0524
# epoch142, loss: 0.2053886268410709
# [Validation Epoch 142] Pixel Accuracy: 0.7134 | Mean IoU: 0.0527
# [Validation Epoch 143] Pixel Accuracy: 0.7337 | Mean IoU: 0.0489
# epoch144, loss: 0.2961746013754017
# [Validation Epoch 144] Pixel Accuracy: 0.7153 | Mean IoU: 0.0534
# [Validation Epoch 145] Pixel Accuracy: 0.7250 | Mean IoU: 0.0534
# epoch146, loss: 0.17812165351850645
# [Validation Epoch 146] Pixel Accuracy: 0.7257 | Mean IoU: 0.0528
# [Validation Epoch 147] Pixel Accuracy: 0.7249 | Mean IoU: 0.0526
# epoch148, loss: 0.1549496128336414
# [Validation Epoch 148] Pixel Accuracy: 0.7232 | Mean IoU: 0.0538
# [Validation Epoch 149] Pixel Accuracy: 0.7247 | Mean IoU: 0.0542
# epoch150, loss: 0.14906321306313788
# [Validation Epoch 150] Pixel Accuracy: 0.7245 | Mean IoU: 0.0533
# [Validation Epoch 151] Pixel Accuracy: 0.7262 | Mean IoU: 0.0534
# epoch152, loss: 0.1551489608137162
# [Validation Epoch 152] Pixel Accuracy: 0.7297 | Mean IoU: 0.0540
# [Validation Epoch 153] Pixel Accuracy: 0.7221 | Mean IoU: 0.0539
# epoch154, loss: 0.15802725736092735
# [Validation Epoch 154] Pixel Accuracy: 0.7250 | Mean IoU: 0.0537
# [Validation Epoch 155] Pixel Accuracy: 0.7208 | Mean IoU: 0.0533
# epoch156, loss: 0.15906981472949405
# [Validation Epoch 156] Pixel Accuracy: 0.7173 | Mean IoU: 0.0539
# [Validation Epoch 157] Pixel Accuracy: 0.7286 | Mean IoU: 0.0517
# epoch158, loss: 0.26941460718984134
# [Validation Epoch 158] Pixel Accuracy: 0.7232 | Mean IoU: 0.0510
# [Validation Epoch 159] Pixel Accuracy: 0.7241 | Mean IoU: 0.0513
# epoch160, loss: 0.19072753424336622
# [Validation Epoch 160] Pixel Accuracy: 0.7219 | Mean IoU: 0.0525
# [Validation Epoch 161] Pixel Accuracy: 0.7259 | Mean IoU: 0.0551
# epoch162, loss: 0.175647121741549
# [Validation Epoch 162] Pixel Accuracy: 0.7228 | Mean IoU: 0.0535
# [Validation Epoch 163] Pixel Accuracy: 0.7271 | Mean IoU: 0.0530
# epoch164, loss: 0.14040766779210542
# [Validation Epoch 164] Pixel Accuracy: 0.7268 | Mean IoU: 0.0546
# [Validation Epoch 165] Pixel Accuracy: 0.7267 | Mean IoU: 0.0543
# epoch166, loss: 0.13229277820050062
# [Validation Epoch 166] Pixel Accuracy: 0.7285 | Mean IoU: 0.0536
# [Validation Epoch 167] Pixel Accuracy: 0.7230 | Mean IoU: 0.0538
# epoch168, loss: 0.13541475474670694
# [Validation Epoch 168] Pixel Accuracy: 0.7257 | Mean IoU: 0.0535
# [Validation Epoch 169] Pixel Accuracy: 0.7243 | Mean IoU: 0.0517
# epoch170, loss: 0.14450642532044713
# [Validation Epoch 170] Pixel Accuracy: 0.7248 | Mean IoU: 0.0542
# [Validation Epoch 171] Pixel Accuracy: 0.7288 | Mean IoU: 0.0524
# epoch172, loss: 0.15273728565527842
# [Validation Epoch 172] Pixel Accuracy: 0.7185 | Mean IoU: 0.0531
# [Validation Epoch 173] Pixel Accuracy: 0.7177 | Mean IoU: 0.0529
# epoch174, loss: 0.22714931206716285
# [Validation Epoch 174] Pixel Accuracy: 0.7284 | Mean IoU: 0.0525
# [Validation Epoch 175] Pixel Accuracy: 0.7288 | Mean IoU: 0.0518
# epoch176, loss: 0.1605365670971818
# [Validation Epoch 176] Pixel Accuracy: 0.7258 | Mean IoU: 0.0537
# [Validation Epoch 177] Pixel Accuracy: 0.7271 | Mean IoU: 0.0540
# epoch178, loss: 0.12476603254921488
# [Validation Epoch 178] Pixel Accuracy: 0.7282 | Mean IoU: 0.0548
# [Validation Epoch 179] Pixel Accuracy: 0.7273 | Mean IoU: 0.0544
# epoch180, loss: 0.11616422530713973
# [Validation Epoch 180] Pixel Accuracy: 0.7267 | Mean IoU: 0.0544
# [Validation Epoch 181] Pixel Accuracy: 0.7295 | Mean IoU: 0.0539
# epoch182, loss: 0.119711612033975
# [Validation Epoch 182] Pixel Accuracy: 0.7290 | Mean IoU: 0.0535
# [Validation Epoch 183] Pixel Accuracy: 0.7216 | Mean IoU: 0.0541
# epoch184, loss: 0.12384091387246991
# [Validation Epoch 184] Pixel Accuracy: 0.7299 | Mean IoU: 0.0536
# [Validation Epoch 185] Pixel Accuracy: 0.7262 | Mean IoU: 0.0539
# epoch186, loss: 0.12487240192981866
# [Validation Epoch 186] Pixel Accuracy: 0.7340 | Mean IoU: 0.0528
# [Validation Epoch 187] Pixel Accuracy: 0.7178 | Mean IoU: 0.0542
# epoch188, loss: 0.12775382636995106
# [Validation Epoch 188] Pixel Accuracy: 0.7261 | Mean IoU: 0.0545
# [Validation Epoch 189] Pixel Accuracy: 0.7041 | Mean IoU: 0.0539
# epoch190, loss: 0.3044920699609505
# [Validation Epoch 190] Pixel Accuracy: 0.7182 | Mean IoU: 0.0536
# [Validation Epoch 191] Pixel Accuracy: 0.7266 | Mean IoU: 0.0500
# epoch192, loss: 0.17066539250887358
# [Validation Epoch 192] Pixel Accuracy: 0.7243 | Mean IoU: 0.0536
# [Validation Epoch 193] Pixel Accuracy: 0.7272 | Mean IoU: 0.0536
# epoch194, loss: 0.11243143722742469
# [Validation Epoch 194] Pixel Accuracy: 0.7228 | Mean IoU: 0.0540
# [Validation Epoch 195] Pixel Accuracy: 0.7269 | Mean IoU: 0.0538
# epoch196, loss: 0.10368044134024736
# [Validation Epoch 196] Pixel Accuracy: 0.7274 | Mean IoU: 0.0540
# [Validation Epoch 197] Pixel Accuracy: 0.7278 | Mean IoU: 0.0534
# epoch198, loss: 0.1040459778364543
# [Validation Epoch 198] Pixel Accuracy: 0.7246 | Mean IoU: 0.0535
# [Validation Epoch 199] Pixel Accuracy: 0.7225 | Mean IoU: 0.0539
# epoch200, loss: 0.11031807887439544
# [Validation Epoch 200] Pixel Accuracy: 0.7274 | Mean IoU: 0.0540
# [Validation Epoch 201] Pixel Accuracy: 0.7240 | Mean IoU: 0.0534
# epoch202, loss: 0.11231233345365131
# [Validation Epoch 202] Pixel Accuracy: 0.7282 | Mean IoU: 0.0538
# [Validation Epoch 203] Pixel Accuracy: 0.7170 | Mean IoU: 0.0539
# epoch204, loss: 0.11537956608111387
# [Validation Epoch 204] Pixel Accuracy: 0.7252 | Mean IoU: 0.0542
# [Validation Epoch 205] Pixel Accuracy: 0.7161 | Mean IoU: 0.0533
# epoch206, loss: 0.11425845779396676
# [Validation Epoch 206] Pixel Accuracy: 0.7102 | Mean IoU: 0.0548
# [Validation Epoch 207] Pixel Accuracy: 0.7233 | Mean IoU: 0.0542
# epoch208, loss: 0.10988451114722661
# [Validation Epoch 208] Pixel Accuracy: 0.7305 | Mean IoU: 0.0522
# [Validation Epoch 209] Pixel Accuracy: 0.7240 | Mean IoU: 0.0533
# epoch210, loss: 0.11303024010343866
# [Validation Epoch 210] Pixel Accuracy: 0.7245 | Mean IoU: 0.0534
# [Validation Epoch 211] Pixel Accuracy: 0.7224 | Mean IoU: 0.0538
# epoch212, loss: 0.11165670678019524
# [Validation Epoch 212] Pixel Accuracy: 0.7291 | Mean IoU: 0.0536
# [Validation Epoch 213] Pixel Accuracy: 0.7248 | Mean IoU: 0.0540
# epoch214, loss: 0.325594314711762
# [Validation Epoch 214] Pixel Accuracy: 0.7278 | Mean IoU: 0.0511
# [Validation Epoch 215] Pixel Accuracy: 0.7232 | Mean IoU: 0.0533
# epoch216, loss: 0.11993779246132452
# [Validation Epoch 216] Pixel Accuracy: 0.7282 | Mean IoU: 0.0528
# [Validation Epoch 217] Pixel Accuracy: 0.7287 | Mean IoU: 0.0534
# epoch218, loss: 0.09370843822566363
# [Validation Epoch 218] Pixel Accuracy: 0.7277 | Mean IoU: 0.0535
# [Validation Epoch 219] Pixel Accuracy: 0.7251 | Mean IoU: 0.0538
# epoch220, loss: 0.08810437824781779
# [Validation Epoch 220] Pixel Accuracy: 0.7254 | Mean IoU: 0.0533
# [Validation Epoch 221] Pixel Accuracy: 0.7262 | Mean IoU: 0.0532
# epoch222, loss: 0.08874695121750727
# [Validation Epoch 222] Pixel Accuracy: 0.7255 | Mean IoU: 0.0533
# [Validation Epoch 223] Pixel Accuracy: 0.7201 | Mean IoU: 0.0533
# epoch224, loss: 0.09691109428448337
# [Validation Epoch 224] Pixel Accuracy: 0.7233 | Mean IoU: 0.0531
# [Validation Epoch 225] Pixel Accuracy: 0.7238 | Mean IoU: 0.0536
# epoch226, loss: 0.09579637986454335
# [Validation Epoch 226] Pixel Accuracy: 0.7248 | Mean IoU: 0.0540
# [Validation Epoch 227] Pixel Accuracy: 0.7275 | Mean IoU: 0.0528
# epoch228, loss: 0.09779152628239039
# [Validation Epoch 228] Pixel Accuracy: 0.7263 | Mean IoU: 0.0530
# [Validation Epoch 229] Pixel Accuracy: 0.7284 | Mean IoU: 0.0528
# epoch230, loss: 0.0970476465606755
# [Validation Epoch 230] Pixel Accuracy: 0.7248 | Mean IoU: 0.0533
# [Validation Epoch 231] Pixel Accuracy: 0.7258 | Mean IoU: 0.0521
# epoch232, loss: 0.09770477681860819
# [Validation Epoch 232] Pixel Accuracy: 0.7187 | Mean IoU: 0.0545
# [Validation Epoch 233] Pixel Accuracy: 0.7248 | Mean IoU: 0.0527
# epoch234, loss: 0.09501721040642523
# [Validation Epoch 234] Pixel Accuracy: 0.7240 | Mean IoU: 0.0537
# [Validation Epoch 235] Pixel Accuracy: 0.7285 | Mean IoU: 0.0477
# epoch236, loss: 0.2692962726885146
# [Validation Epoch 236] Pixel Accuracy: 0.7170 | Mean IoU: 0.0540
# [Validation Epoch 237] Pixel Accuracy: 0.7233 | Mean IoU: 0.0541
# epoch238, loss: 0.11364639022356861
# [Validation Epoch 238] Pixel Accuracy: 0.7211 | Mean IoU: 0.0537
# [Validation Epoch 239] Pixel Accuracy: 0.7264 | Mean IoU: 0.0527
# epoch240, loss: 0.09009014047518536
# [Validation Epoch 240] Pixel Accuracy: 0.7241 | Mean IoU: 0.0537
# [Validation Epoch 241] Pixel Accuracy: 0.7292 | Mean IoU: 0.0533
# epoch242, loss: 0.07916935226255721
# [Validation Epoch 242] Pixel Accuracy: 0.7272 | Mean IoU: 0.0531
# [Validation Epoch 243] Pixel Accuracy: 0.7247 | Mean IoU: 0.0538
# epoch244, loss: 0.07844212896876283
# [Validation Epoch 244] Pixel Accuracy: 0.7225 | Mean IoU: 0.0537
# [Validation Epoch 245] Pixel Accuracy: 0.7278 | Mean IoU: 0.0527
# epoch246, loss: 0.08505649805314593
# [Validation Epoch 246] Pixel Accuracy: 0.7274 | Mean IoU: 0.0523
# [Validation Epoch 247] Pixel Accuracy: 0.7265 | Mean IoU: 0.0534
# epoch248, loss: 0.08547167134072099
# [Validation Epoch 248] Pixel Accuracy: 0.7269 | Mean IoU: 0.0524
# [Validation Epoch 249] Pixel Accuracy: 0.7263 | Mean IoU: 0.0526

# %% [markdown]
# ## Plot Loss Function and Metrics

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,3,1)
plt.plot(loss_track)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Over Epochs')
plt.grid(True)

plt.subplot(1,3,2)
plt.plot(pixel_scores)
plt.xlabel('Epoch')
plt.ylabel('Pixel Accuracy')
plt.title('Pixel Accuracy of Validation Set')
plt.grid(True)

plt.subplot(1,3,3)
for cls in range(n_class-1):
    plt.plot(range(epochs), iu_scores[:, cls+1], label=label_name[cls+1])

plt.xlabel('Epoch')
plt.ylabel('IoU')
plt.title('Per-Class IoU of Validation Set')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.legend(prop={'size': 8, 'family': 'serif'}, loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Validate Model and Visualize Results on Train Dataset

# %%
fcn_model.eval()
img, seg = next(iter(train_loader))

with torch.no_grad():
    out = fcn_model(img.cuda())
    plt_cnt=1
    plt.figure(figsize=(8,10))
    labelnames = []

    for idx in range(0,6):
        #print(out.shape)
        y_predict = out[idx].cpu().numpy()
        #print(y_predict.shape)
        y_predict = out[idx].argmax(dim=0).cpu().numpy()
        #print(y_predict.shape)

        labels_temp = ''
        for i in np.unique(y_predict).tolist():
            #print('Predcited label',label_name[i])
            labels_temp = label_name[i] + ', \n' + labels_temp

            color_mask = np.zeros((*y_predict.shape, 3))
            for i, color in enumerate(label_color):
                color_mask[seg[idx]==i] = np.array(color)
            
            color_mask_predict = np.zeros((*y_predict.shape, 3))
            for i, color in enumerate(label_color):
                color_mask_predict[y_predict==i] = np.array(color)
        labelnames.append(labels_temp)


        pltimg = np.transpose(img[idx],(1, 2, 0))
        mean=torch.tensor([0.485, 0.456, 0.406])
        std=torch.tensor([0.229, 0.224, 0.225])
        pltimg = std * pltimg + mean

        plt.subplot(6,3,plt_cnt)
        plt.imshow(np.clip(pltimg.numpy(),0,1))
        plt.title('Original Image')
        plt_cnt+=1
        plt.subplot(6,3,plt_cnt)
        plt.imshow(color_mask.astype(np.int32))
        plt.title('Segmented Image')
        plt_cnt+=1
        plt.subplot(6,3,plt_cnt)
        plt.imshow(color_mask_predict.astype(np.int32))
        plt.text(300,255,labelnames[idx],fontsize=8)
        plt.title('Predicted Segment')
        plt_cnt+=1


    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Validate Model and Visualize Results on Validation Dataset

# %%
fcn_model.eval()
val_loader = DataLoader(valdataset, batch_size=6, num_workers=16, shuffle=True)
img, seg = next(iter(val_loader))

with torch.no_grad():
    out = fcn_model(img.cuda())
    plt_cnt=1
    plt.figure(figsize=(8,10))
    labelnames = []

    for idx in range(0,6):
        #print(out.shape)
        y_predict = out[idx].cpu().numpy()
        #print(y_predict.shape)
        y_predict = out[idx].argmax(dim=0).cpu().numpy()
        #print(y_predict.shape)

        labels_temp = ''
        for i in np.unique(y_predict).tolist():
            #print('Predcited label',label_name[i])
            labels_temp = label_name[i] + ', \n' + labels_temp

            color_mask = np.zeros((*y_predict.shape, 3))
            for i, color in enumerate(label_color):
                color_mask[seg[idx]==i] = np.array(color)
            
            color_mask_predict = np.zeros((*y_predict.shape, 3))
            for i, color in enumerate(label_color):
                color_mask_predict[y_predict==i] = np.array(color)
        labelnames.append(labels_temp)


        pltimg = np.transpose(img[idx],(1, 2, 0))
        mean=torch.tensor([0.485, 0.456, 0.406])
        std=torch.tensor([0.229, 0.224, 0.225])
        pltimg = std * pltimg + mean

        plt.subplot(6,3,plt_cnt)
        plt.imshow(np.clip(pltimg.numpy(),0,1))
        plt.title('Original Image')
        plt_cnt+=1
        plt.subplot(6,3,plt_cnt)
        plt.imshow(color_mask.astype(np.int32))
        plt.title('Segmented Image')
        plt_cnt+=1
        plt.subplot(6,3,plt_cnt)
        plt.imshow(color_mask_predict.astype(np.int32))
        plt.text(300,255,labelnames[idx],fontsize=8)
        plt.title('Predicted Segment')
        plt_cnt+=1


    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Test Codes

# %%
# print(out.min(), out.max(), out.mean(),out.shape)
# print(np.unique(seg.numpy(), return_counts=True))
# print(img.shape,seg.shape,out.shape,preds.shape)
# print(np.unique(seg.numpy(), return_counts=True))

# for i in range(0,21):
#     print(out[1,i].max())

#out = out[0]
#preds = torch.argmax(out[0], dim=0)

# plt.figure(figsize=(12,4))
# plt.subplot(1,3,1)
# plt.imshow(np.transpose(img[1], (1, 2, 0)))
# plt.title('Original Image')
# plt.subplot(1,3,2)
# plt.imshow(seg[1])
# plt.title('Original Masked Image')
# plt.subplot(1,3,3)
# plt.imshow(preds.detach().cpu())
# plt.title('Predicted Masked Image')

#criterion = nn.BCEWithLogitsLoss()
#optimizer = optim.RMSprop(fcn_model.parameters(), lr=lr, momentum=momentum, weight_decay=w_decay)

##seg = self.mask_transforms(seg)
#seg = seg.resize((256,256), resample=Image.NEAREST)
#seg = np.array(seg).astype(np.int64)
#seg[seg == 255] = 255
#seg = torch.from_numpy(seg).long()
#seg = seg.squeeze(0)

# self.mask_transforms = transforms.Compose([
#                         transforms.Resize((256, 256), interpolation=transforms.InterpolationMode.NEAREST),
#                         transforms.ToTensor()])

# %% [markdown]
# #### Reference Links
# - https://debuggercafe.com/semantic-segmentation-using-pytorch-fcn-resnet/
# - https://www.kaggle.com/code/datnguyen1235/pascal-voc-with-resunet-pytorch
# - https://www.kaggle.com/code/xixihaha318/sematicsegmentation-with-pytorch
# - https://github.com/initiativealmendra/DL-architectures/blob/master/FCN.py
# - https://github.com/wkentaro/pytorch-fcn/blob/main/examples/voc/train_fcn16s.py
# - https://github.com/pochih/FCN-pytorch/blob/master/python/train.py
# - https://www.kaggle.com/code/mrinath/segmentation-baseline
# - https://github.com/LaurentVeyssier/Semantic-Segmentation-with-Fully-Convolution-Network?tab=readme-ov-file
